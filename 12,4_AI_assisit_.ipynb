# %% [markdown]
# 2303A52008
#
# BATCH 43
#
# K.KEERTHAN

# %% [markdown]
# TASK 01

# %%
def bubble_sort(scores):
    n = len(scores)
    # Outer loop for passes through the list
    for i in range(n - 1):
        swapped = False  # Flag to detect if any swaps occurred in this pass
        # Inner loop for comparisons and swaps in the current pass
        for j in range(0, n - i - 1):
            # Compare adjacent elements
            if scores[j] > scores[j + 1]:
                # If current element is greater than the next, swap them
                scores[j], scores[j + 1] = scores[j + 1], scores[j]
                swapped = True  # Mark that a swap occurred
        # Early termination condition: if no two elements were swapped
        # by inner loop, then the list is sorted
        if not swapped:
            break
    return scores

# Sample input of student scores
student_scores = [85, 72, 93, 65, 78, 90, 88, 70, 95]

print("Original scores:", student_scores)

# Sort the scores using Bubble Sort
sorted_scores = bubble_sort(list(student_scores)) # Create a copy to keep original untouched

print("Sorted scores:", sorted_scores)
# Out:
# Original scores: [85, 72, 93, 65, 78, 90, 88, 70, 95]
# Sorted scores: [65, 70, 72, 78, 85, 88, 90, 93, 95]

# %% [markdown]
# TASK 02

# %%
def insertion_sort(scores):
    # Traverse through 1 to len(scores)
    for i in range(1, len(scores)):
        key = scores[i] # Current element to be compared
        j = i - 1 # Index of the previous element

        # Move elements of scores[0..i-1], that are greater than key,
        # to one position ahead of their current position
        while j >= 0 and key < scores[j]:
            scores[j + 1] = scores[j]
            j -= 1
        scores[j + 1] = key # Place key at its correct position
    return scores

print("Defined the insertion_sort function.")
# Out:
# Defined the insertion_sort function.

# %%
import random

# 1. Start with the sorted_scores list
# sorted_scores is available from the previous execution

# 2. Create a new list, nearly_sorted_scores, by making a copy of sorted_scores
nearly_sorted_scores = list(sorted_scores)

# 3. Introduce a few minor changes to nearly_sorted_scores to make it 'nearly sorted'.
# For instance, swap two adjacent elements, or move one element slightly out of its sorted position.
# Ensure the list remains mostly sorted but not perfectly.

# Example: Swap two adjacent elements (e.g., index 2 and 3)
if len(nearly_sorted_scores) >= 4:
    # Swapping elements at index 2 and 3: 72 and 78 become 78 and 72
    nearly_sorted_scores[2], nearly_sorted_scores[3] = nearly_sorted_scores[3], nearly_sorted_scores[2]

# Example: Slightly move another element
# Move element at index 0 (65) to index 1, pushing others slightly
# We'll just swap one more to keep it simple and illustrate 'nearly' sorted
if len(nearly_sorted_scores) >= 2:
    nearly_sorted_scores[0], nearly_sorted_scores[1] = nearly_sorted_scores[1], nearly_sorted_scores[0]


print("Original sorted scores:", sorted_scores)
print("Nearly sorted scores:", nearly_sorted_scores)
# Out:
# Original sorted scores: [65, 70, 72, 78, 85, 88, 90, 93, 95]
# Nearly sorted scores: [70, 65, 78, 72, 85, 88, 90, 93, 95]

# %%
print("Nearly sorted data for comparison:", nearly_sorted_scores)

# 1. Make a copy of the nearly_sorted_scores list for bubble_sort
bubble_input = list(nearly_sorted_scores)

# 2. Call the bubble_sort function and store the result
bubble_sorted_result = bubble_sort(bubble_input)

# 3. Print the descriptive label and bubble_sorted_result
print("Bubble Sort result:", bubble_sorted_result)

# 4. Make another copy of the nearly_sorted_scores list for insertion_sort
insertion_input = list(nearly_sorted_scores)

# 5. Call the insertion_sort function and store the result
insertion_sorted_result = insertion_sort(insertion_input)

# 6. Print the descriptive label and insertion_sorted_result
print("Insertion Sort result:", insertion_sorted_result)
# Out:
# Nearly sorted data for comparison: [70, 65, 78, 72, 85, 88, 90, 93, 95]
# Bubble Sort result: [65, 70, 72, 78, 85, 88, 90, 93, 95]
# Insertion Sort result: [65, 70, 72, 78, 85, 88, 90, 93, 95]

# %% [markdown]
# TASK 03

# %%
def linear_search(roll_numbers, target_roll_number):
    """
    Searches for a target roll number in a list using linear search.

    Args:
        roll_numbers (list): A list of student roll numbers.
        target_roll_number (int): The roll number to search for.

    Returns:
        int: The index of the target roll number if found, otherwise -1.
    """
    for index, roll_number in enumerate(roll_numbers):
        if roll_number == target_roll_number:
            return index
    return -1

print("Defined the linear_search function.")
# Out:
# Defined the linear_search function.

# %%
def binary_search(roll_numbers, target_roll_number):
    """
    Searches for a target roll number in a *sorted* list using binary search.

    Args:
        roll_numbers (list): A sorted list of student roll numbers.
        target_roll_number (int): The roll number to search for.

    Returns:
        int: The index of the target roll number if found, otherwise -1.
    """
    low = 0
    high = len(roll_numbers) - 1

    while low <= high:
        mid = (low + high) // 2

        if roll_numbers[mid] == target_roll_number:
            return mid
        elif roll_numbers[mid] < target_roll_number:
            low = mid + 1
        else:
            high = mid - 1
    return -1

print("Defined the binary_search function.")
# Out:
# Defined the binary_search function.

# %%
import random

# Prepare an unsorted list of roll numbers
unsorted_roll_numbers = [101, 105, 103, 100, 108, 102, 107, 104, 106]
print("Unsorted roll numbers:", unsorted_roll_numbers)

# Create a sorted list of roll numbers from the unsorted list
sorted_roll_numbers = sorted(unsorted_roll_numbers)
print("Sorted roll numbers:", sorted_roll_numbers)

# Define target roll numbers for testing
existing_roll_number = 104
non_existing_roll_number = 109

print(f"\nTarget existing roll number: {existing_roll_number}")
print(f"Target non-existing roll number: {non_existing_roll_number}")
# Out:
# Unsorted roll numbers: [101, 105, 103, 100, 108, 102, 107, 104, 106]
# Sorted roll numbers: [100, 101, 102, 103, 104, 105, 106, 107, 108]
#
# Target existing roll number: 104
# Target non-existing roll number: 109

# %%
print("\n--- Linear Search Results ---")
# Linear Search - Existing roll number
index_linear_existing = linear_search(unsorted_roll_numbers, existing_roll_number)
if index_linear_existing != -1:
    print(f"Linear Search: Roll number {existing_roll_number} found at index {index_linear_existing} in unsorted list.")
else:
    print(f"Linear Search: Roll number {existing_roll_number} not found in unsorted list.")

# Linear Search - Non-existing roll number
index_linear_non_existing = linear_search(unsorted_roll_numbers, non_existing_roll_number)
if index_linear_non_existing != -1:
    print(f"Linear Search: Roll number {non_existing_roll_number} found at index {index_linear_non_existing} in unsorted list.")
else:
    print(f"Linear Search: Roll number {non_existing_roll_number} not found in unsorted list.")

print("\n--- Binary Search Results ---")
# Binary Search - Existing roll number
index_binary_existing = binary_search(sorted_roll_numbers, existing_roll_number)
if index_binary_existing != -1:
    print(f"Binary Search: Roll number {existing_roll_number} found at index {index_binary_existing} in sorted list.")
else:
    print(f"Binary Search: Roll number {existing_roll_number} not found in sorted list.")

# Binary Search - Non-existing roll number
index_binary_non_existing = binary_search(sorted_roll_numbers, non_existing_roll_number)
if index_binary_non_existing != -1:
    print(f"Binary Search: Roll number {non_existing_roll_number} found at index {index_binary_non_existing} in sorted list.")
else:
    print(f"Binary Search: Roll number {non_existing_roll_number} not found in sorted list.")
# Out:
# --- Linear Search Results ---
# Linear Search: Roll number 104 found at index 7 in unsorted list.
# Linear Search: Roll number 109 not found in unsorted list.
#
# --- Binary Search Results ---
# Binary Search: Roll number 104 found at index 4 in sorted list.
# Binary Search: Roll number 109 not found in sorted list.

# %% [markdown]
# ```markdown
# ## Comparison of Linear Search and Binary Search Algorithms
#
# This section compares Linear Search and Binary Search based on key characteristics.
#
# ### 1. Applicability
# *   **Linear Search:** Can be applied to any list or array, whether it is sorted or unsorted. It does not require any pre-processing of the data.
# *   **Binary Search:** Requires the list or array to be **sorted** in advance. If the data is unsorted, it must first be sorted, which adds an overhead (e.g., O(n log n) for comparison sorts).
#
# ### 2. Time Complexity
# *   **Linear Search:**
#     *   **Best Case:** O(1) - When the target element is found at the very first position.
#     *   **Average Case:** O(n) - When the target element is found somewhere in the middle.
#     *   **Worst Case:** O(n) - When the target element is at the end of the list or not present at all. In the worst case, it has to check every element.
# *   **Binary Search:**
#     *   **Best Case:** O(1) - When the target element is found at the middle of the list in the first comparison.
#     *   **Average Case:** O(log n) - The search space is halved in each step.
#     *   **Worst Case:** O(log n) - The search space is continually halved until the element is found or the search space is exhausted. This makes it significantly faster for large datasets compared to Linear Search.
#
# ### 3. Performance Differences
# *   For **small lists**, the performance difference between Linear Search and Binary Search might not be significant, and Linear Search can even be slightly faster due to its simpler logic and lack of pre-sorting overhead.
# *   For **large lists**, Binary Search is dramatically faster than Linear Search, assuming the list is already sorted. Its logarithmic time complexity means that the number of operations grows very slowly as the input size increases. For example, searching a list of a million items: Linear Search might take up to a million comparisons, while Binary Search would take around 20 comparisons (log base 2 of 1,000,000 is approximately 19.9).
# *   The **cost of sorting** the list must be considered. If a list is unsorted and will only be searched once, Linear Search might be more efficient than sorting (O(n log n)) and then performing a Binary Search (O(log n)). If the list will be searched multiple times, the initial sorting cost is amortized, making Binary Search the superior choice.
#
# ### 4. Use Cases
# *   **Linear Search:**
#     *   When the list is small.
#     *   When the list is unsorted and will not be searched frequently enough to justify the cost of sorting.
#     *   When the target element is likely to be found early in the list.
#     *   In situations where simplicity of implementation is prioritized over performance for small data.
# *   **Binary Search:**
#     *   When the list is large and **sorted**.
#     *   When the list is static (does not change often) and will be searched frequently.
#     *   In databases and data structures (like binary search trees) where efficient retrieval from sorted data is crucial.
#     *   Used in algorithms that rely on repeatedly halving the search space, such as finding the square root of a number or implementing search functionality in dictionaries/maps.
#
# In summary, while Linear Search is simple and versatile for any list, Binary Search offers superior performance for large, sorted datasets, making it a critical algorithm in computer science for efficiency.

# %% [markdown]
# TASK 04

# %%
def quick_sort(arr):
    """
    Sorts a list of elements using the Quick Sort algorithm.

    Quick Sort is a highly efficient, comparison-based sorting algorithm that
    uses a divide-and-conquer approach. It works by selecting a 'pivot' element
    from the array and partitioning the other elements into two sub-arrays,
    according to whether they are less than or greater than the pivot.
    The sub-arrays are then recursively sorted.

    Args:
        arr (list): The list of elements to be sorted. It can contain any
                    comparable data types (e.g., numbers).

    Returns:
        list: A new list containing the same elements as the input list,
              but sorted in ascending order.

    How Recursion Works:
    1. Base Case: If the list has 0 or 1 element, it is already sorted,
       so it is returned directly. This stops the recursion.
    2. Divide: A pivot element is chosen (here, the last element). The rest
       of the list is then divided into two sub-lists: `less` (elements
       smaller than the pivot) and `greater` (elements greater than or equal
       to the pivot).
    3. Conquer: The `quick_sort` function is recursively called on both the
       `less` and `greater` sub-lists. This process continues until the
       base case is met for all sub-lists.
    4. Combine: Once the recursive calls return the sorted `less` and `greater`
       sub-lists, they are concatenated together with the pivot in between
       ([sorted_less] + [pivot] + [sorted_greater]) to produce the final
       sorted list.
    """
    # 2. Implement the base case for the recursion
    if len(arr) <= 1:
        return arr

    # 3. Choose a pivot element (last element) and remove it from the list for partitioning
    pivot = arr.pop() # Removes the last element and returns it

    # 4. Create two empty lists for partitioning
    less = []
    greater = []

    # 5. Iterate and append to less or greater based on comparison with pivot
    for element in arr:
        if element < pivot:
            less.append(element)
        else:
            greater.append(element)

    # 6. Recursively call quick_sort on the less and greater lists
    # 7. Combine the sorted less list, the pivot, and the sorted greater list
    return quick_sort(less) + [pivot] + quick_sort(greater)

print("Defined the quick_sort function.")
# Out:
# Defined the quick_sort function.

# %%
def merge_sort(arr):
    """
    Sorts a list of elements using the Merge Sort algorithm.

    Merge Sort is an efficient, comparison-based, divide-and-conquer sorting algorithm.
    It works by recursively dividing an unsorted list into n sublists, each containing
    one element (a list of one element is considered sorted). Then, it repeatedly merges
    sublists to produce new sorted sublists until there is only one sorted list remaining.

    Args:
        arr (list): The list of elements to be sorted. It can contain any
                    comparable data types (e.g., numbers).

    Returns:
        list: A new list containing the same elements as the input list,
              but sorted in ascending order.

    How Recursion Works:
    1. Base Case: If the list has 0 or 1 element, it is considered sorted and returned
       directly. This is the termination condition for the recursion.
    2. Divide: If the list has more than one element, it is divided into two roughly
       equal halves (left_half and right_half) at the middle index.
    3. Conquer: The `merge_sort` function is recursively called on both `left_half`
       and `right_half`. This continues to divide the lists until the base case is reached
       for all sub-lists.
    4. Combine: Once the recursive calls return the sorted sub-lists, a helper function
       `_merge` is used to combine these two sorted halves back into a single, fully sorted list.
    """
    # 2. Implement the base case for the recursion
    if len(arr) <= 1:
        return arr

    # 3. If the list has more than one element, find the middle index
    mid = len(arr) // 2

    # 4. Create two sub-lists, left_half and right_half
    left_half = arr[:mid]
    right_half = arr[mid:]

    # 5. Recursively call merge_sort on left_half and right_half
    sorted_left = merge_sort(left_half)
    sorted_right = merge_sort(right_half)

    # 6. Implement a helper function `_merge` and call it to combine results
    # This helper function is typically nested or defined separately.
    # For clarity, let's define it as a local helper or assume it's external for now,
    # but include its logic here.
    def _merge(left, right):
        merged_list = []
        i = j = 0

        while i < len(left) and j < len(right):
            if left[i] < right[j]:
                merged_list.append(left[i])
                i += 1
            else:
                merged_list.append(right[j])
                j += 1

        # Append any remaining elements from left or right (if one list is longer)
        merged_list.extend(left[i:])
        merged_list.extend(right[j:])
        return merged_list

    return _merge(sorted_left, sorted_right)

print("Defined the merge_sort function.")
# Out:
# Defined the merge_sort function.

# %%
import random

# 2. Generate a list named random_data containing a suitable number of random integers
random_data = [random.randint(1, 100) for _ in range(18)] # 18 integers between 1 and 100

# 3. Create a new list named sorted_data by sorting random_data
sorted_data = sorted(random_data)

# 4. Create a new list named reverse_sorted_data by sorting random_data in descending order, or by reversing sorted_data
reverse_sorted_data = sorted(random_data, reverse=True)
# Alternatively: reverse_sorted_data = sorted_data[::-1]

# 5. Print all three lists, clearly labeled, to inspect their contents
print("Random Data:", random_data)
print("Sorted Data:", sorted_data)
print("Reverse-Sorted Data:", reverse_sorted_data)
# Out:
# Random Data: [78, 43, 35, 68, 44, 81, 55, 26, 30, 77, 88, 27, 61, 64, 2, 55, 24, 24]
# Sorted Data: [2, 24, 24, 26, 27, 30, 35, 43, 44, 55, 55, 61, 64, 68, 77, 78, 81, 88]
# Reverse-Sorted Data: [88, 81, 78, 77, 68, 64, 61, 55, 55, 44, 43, 35, 30, 27, 26, 24, 24, 2]

# %%
print("\n--- Quick Sort Results ---")

# Test with Random Data
random_data_qs = list(random_data)
print(f"Original Random Data:       {random_data_qs}")
print(f"Quick Sort (Random Data):   {quick_sort(random_data_qs)}")

# Test with Sorted Data
sorted_data_qs = list(sorted_data)
print(f"Original Sorted Data:       {sorted_data_qs}")
print(f"Quick Sort (Sorted Data):   {quick_sort(sorted_data_qs)}")

# Test with Reverse-Sorted Data
reverse_sorted_data_qs = list(reverse_sorted_data)
print(f"Original Reverse-Sorted Data: {reverse_sorted_data_qs}")
print(f"Quick Sort (Reverse-Sorted Data): {quick_sort(reverse_sorted_data_qs)}")

print("\n--- Merge Sort Results ---")

# Test with Random Data
random_data_ms = list(random_data)
print(f"Original Random Data:       {random_data_ms}")
print(f"Merge Sort (Random Data):   {merge_sort(random_data_ms)}")

# Test with Sorted Data
sorted_data_ms = list(sorted_data)
print(f"Original Sorted Data:       {sorted_data_ms}")
print(f"Merge Sort (Sorted Data):   {merge_sort(sorted_data_ms)}")

# Test with Reverse-Sorted Data
reverse_sorted_data_ms = list(reverse_sorted_data)
print(f"Original Reverse-Sorted Data: {reverse_sorted_data_ms}")
print(f"Merge Sort (Reverse-Sorted Data): {merge_sort(reverse_sorted_data_ms)}")
# Out:
# --- Quick Sort Results ---
# Original Random Data:       [78, 43, 35, 68, 44, 81, 55, 26, 30, 77, 88, 27, 61, 64, 2, 55, 24, 24]
# Quick Sort (Random Data):   [2, 24, 24, 26, 27, 30, 35, 43, 44, 55, 55, 61, 64, 68, 77, 78, 81, 88]
# Original Sorted Data:       [2, 24, 24, 26, 27, 30, 35, 43, 44, 55, 55, 61, 64, 68, 77, 78, 81, 88]
# Quick Sort (Sorted Data):   [2, 24, 24, 26, 27, 30, 35, 43, 44, 55, 55, 61, 64, 68, 77, 78, 81, 88]
# Original Reverse-Sorted Data: [88, 81, 78, 77, 68, 64, 61, 55, 55, 44, 43, 35, 30, 27, 26, 24, 24, 2]
# Quick Sort (Reverse-Sorted Data): [2, 24, 24, 26, 27, 30, 35, 43, 44, 55, 55, 61, 64, 68, 77, 78, 81, 88]
#
# --- Merge Sort Results ---
# Original Random Data:       [78, 43, 35, 68, 44, 81, 55, 26, 30, 77, 88, 27, 61, 64, 2, 55, 24, 24]
# Merge Sort (Random Data):   [2, 24, 24, 26, 27, 30, 35, 43, 44, 55, 55, 61, 64, 68, 77, 78, 81, 88]
# Original Sorted Data:       [2, 24, 24, 26, 27, 30, 35, 43, 44, 55, 55, 61, 64, 68, 77, 78, 81, 88]
# ...

# %% [markdown]
# TASK 05

# %%
def find_duplicates_naive(user_ids):
    """
    Detects duplicate user IDs in a list using a naive approach with nested loops.

    This function iterates through the list of user IDs, comparing each element
    with every subsequent element to find duplicates. It collects and returns
    unique duplicate IDs found.

    Args:
        user_ids (list): A list of user IDs to check for duplicates.

    Returns:
        list: A list of unique duplicate user IDs found in the input list.
    """
    duplicates = []
    n = len(user_ids)

    # Outer loop iterates from the first element up to, but not including, the last element
    for i in range(n - 1):
        # Inner loop iterates from the element *after* the current outer loop element
        # up to the end of the user_ids list
        for j in range(i + 1, n):
            # Compare the element from the outer loop with the element from the inner loop
            if user_ids[i] == user_ids[j]:
                # If the two elements are equal and the element is not already in the duplicates list,
                # add it to the duplicates list.
                if user_ids[i] not in duplicates:
                    duplicates.append(user_ids[i])

    return duplicates

print("Defined the 'find_duplicates_naive' function.")

# Example usage for testing the function
# sample_user_ids = [101, 102, 103, 101, 104, 105, 102, 106, 101]
# found_duplicates = find_duplicates_naive(sample_user_ids)
# print(f"Sample User IDs: {sample_user_ids}")
# print(f"Found duplicates: {found_duplicates}") # Expected: [101, 102]
# Out:
# Defined the 'find_duplicates_naive' function.

# %%
def find_duplicates_optimized(user_ids):
    """
    Detects duplicate user IDs in a list using an optimized approach with a set.

    This function efficiently identifies duplicate user IDs by using a set to track
    seen IDs, providing O(1) average time complexity for lookups. It collects
    and returns unique duplicate IDs found.

    Args:
        user_ids (list): A list of user IDs to check for duplicates.

    Returns:
        list: A list of unique duplicate user IDs found in the input list.
    """
    seen_ids = set() # To store unique IDs encountered
    duplicates = []  # To store unique duplicate IDs found

    for user_id in user_ids:
        # If the user_id has been seen before, it's a duplicate
        if user_id in seen_ids:
            # Add to duplicates list only if not already added (to ensure unique duplicates)
            if user_id not in duplicates:
                duplicates.append(user_id)
        else:
            # If not seen, add to the set of seen IDs
            seen_ids.add(user_id)

    return duplicates

print("Defined the 'find_duplicates_optimized' function.")

# Example usage for testing the function
# sample_user_ids = [101, 102, 103, 101, 104, 105, 102, 106, 101]
# found_duplicates = find_duplicates_optimized(sample_user_ids)
# print(f"Sample User IDs: {sample_user_ids}")
# print(f"Found duplicates (optimized): {found_duplicates}") # Expected: [101, 102]
# Out:
# Defined the 'find_duplicates_optimized' function.

# %%
import random

# 1. Define a list of possible user ID ranges or starting points
# To ensure duplicates are likely, we'll keep the range relatively small
# and generate more IDs than the range size, or explicitly add duplicates.

def generate_user_ids_with_duplicates(num_ids=20, id_range=(1000, 1020), num_duplicates=5):
    user_ids = []
    # Generate initial unique IDs
    unique_ids_pool = list(range(id_range[0], id_range[1] + 1))

    # Ensure we don't try to generate more unique IDs than available in the pool
    actual_unique_ids_to_generate = min(num_ids - num_duplicates, len(unique_ids_pool))

    # Add a base set of unique IDs
    user_ids.extend(random.sample(unique_ids_pool, actual_unique_ids_to_generate))

    # Add some additional IDs, which will likely introduce duplicates
    # or ensure some duplicates are present by picking from the existing set
    remaining_ids_to_generate = num_ids - len(user_ids)
    for _ in range(remaining_ids_to_generate):
        # Randomly choose an ID from the original unique pool to ensure potential duplicates
        user_ids.append(random.choice(unique_ids_pool))

    random.shuffle(user_ids) # Shuffle to mix duplicates throughout the list
    return user_ids

# Generate a list of user IDs with duplicates
test_user_ids = generate_user_ids_with_duplicates(num_ids=25, id_range=(1000, 1015), num_duplicates=10)

print("Generated Test User IDs with Duplicates:", test_user_ids)
print(f"Total IDs: {len(test_user_ids)}")
print(f"Number of unique IDs if no duplicates were present (based on range): {1015 - 1000 + 1}")

# Verify some duplicates (optional, for debugging)
from collections import Counter
id_counts = Counter(test_user_ids)
duplicated_items = [id for id, count in id_counts.items() if count > 1]
print("Expected Duplicates (from generated list, for verification):", duplicated_items)
# Out:
# Generated Test User IDs with Duplicates: [1009, 1011, 1007, 1008, 1009, 1009, 1006, 1004, 1011, 1002, 1013, 1008, 1014, 1011, 1010, 1012, 1003, 1009, 1010, 1005, 1015, 1000, 1007, 1001, 1005]
# Total IDs: 25
# Number of unique IDs if no duplicates were present (based on range): 16
# Expected Duplicates (from generated list, for verification): [1009, 1011, 1007, 1008, 1010, 1005]

# %%
print("\n--- Demonstrating Duplicate Detection Algorithms ---")
print("Test Data:", test_user_ids)

# Demonstrate Naive Approach
naive_duplicates = find_duplicates_naive(test_user_ids)
print("Naive Duplicate Detection Result:", naive_duplicates)

# Demonstrate Optimized Approach
optimized_duplicates = find_duplicates_optimized(test_user_ids)
print("Optimized Duplicate Detection Result:", optimized_duplicates)
# Out:
# --- Demonstrating Duplicate Detection Algorithms ---
# Test Data: [1009, 1011, 1007, 1008, 1009, 1009, 1006, 1004, 1011, 1002, 1013, 1008, 1014, 1011, 1010, 1012, 1003, 1009, 1010, 1005, 1015, 1000, 1007, 1001, 1005]
# Naive Duplicate Detection Result: [1009, 1011, 1007, 1008, 1010, 1005]
# Optimized Duplicate Detection Result: [1009, 1011, 1008, 1010, 1007, 1005]
